# %%
import pandas as pd
import numpy as np
x=pd.read_csv("work.csv")
x
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes         Non-Travel        489                Hardware
# 1    26        No         Non-Travel        841                Hardware
# 2    48        No      Travel_Rarely        437         Human Resources
# 3    38       Yes      Travel_Rarely       1403  Research & Development
# 4    54       Yes         Non-Travel        993                Software
# ..  ...       ...                ...        ...                     ...
# 95   54        No         Non-Travel       1258         Human Resources
# 96   39       Yes  Travel_Frequently       1092                 Support
# 97   51        No         Non-Travel        977                Software
# 98   38       Yes  Travel_Frequently        810                Hardware
# 99   23        No         Non-Travel       1222         Human Resources
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
x.groupby(["Age"])

# %%
y=x.groupby(["Age","DailyRate"])
print(y.groups)
# Out:
# {(19, 383): [75], (20, 348): [50], (20, 468): [18], (20, 571): [58], (20, 623): [40], (20, 799): [68], (21, 183): [14], (21, 268): [81], (22, 112): [69], (22, 405): [65], (23, 823): [82], (23, 1222): [99], (24, 478): [79], (24, 1265): [91], (25, 897): [47], (25, 1286): [56], (26, 841): [1], (26, 983): [51], (26, 1024): [90], (27, 203): [10], (27, 259): [5], (27, 1273): [85], (27, 1304): [11], (28, 511): [71], (28, 1159): [9], (29, 568): [86], (29, 693): [15], (30, 511): [16], (30, 640): [21], (30, 838): [93], (31, 1469): [72], (32, 548): [32], (32, 817): [88], (32, 1241): [20], (33, 432): [12], (33, 594): [53], (34, 1185): [34], (34, 1387): [23], (35, 186): [24], (36, 179): [28], (36, 293): [83], (36, 844): [76], (37, 127): [60], (37, 297): [64], (37, 1032): [54], (37, 1174): [27], (37, 1242): [74], (38, 538): [63], (38, 810): [98], (38, 1295): [36], (38, 1297): [22], (38, 1396): [62], (38, 1403): [3], (39, 1092): [96], (40, 237): [89], (40, 830): [39], (40, 1381): [73], (41, 489): [
# ...

# %%
print(x.groupby(["Age"]).groups)
# Out:
# {19: [75], 20: [18, 40, 50, 58, 68], 21: [14, 81], 22: [65, 69], 23: [82, 99], 24: [79, 91], 25: [47, 56], 26: [1, 51, 90], 27: [5, 10, 11, 85], 28: [9, 71], 29: [15, 86], 30: [16, 21, 93], 31: [72], 32: [20, 32, 88], 33: [12, 53], 34: [23, 34], 35: [24], 36: [28, 76, 83], 37: [27, 54, 60, 64, 74], 38: [3, 22, 36, 62, 63, 98], 39: [96], 40: [39, 73, 89], 41: [0, 26, 52], 43: [41, 45], 44: [49, 67, 87], 45: [77], 47: [61, 66, 80], 48: [2, 13], 49: [17, 29, 30, 33, 38], 50: [6, 37, 57, 84, 94], 51: [25, 97], 53: [31, 70], 54: [4, 46, 92, 95], 55: [55], 56: [8, 43, 59], 57: [48], 58: [7, 78], 59: [19, 35], 60: [42, 44]}

# %%
print(x.get_group("489"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 print(x.get_group("489"))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'get_group'

# %%
print(x.groupby(["Attrition"]).max())
# Out:
#            Age BusinessTravel  DailyRate Department  DistanceFromHome  \
# Attrition
# No          60  Travel_Rarely       1469    Support                50
# Yes         60  Travel_Rarely       1485    Support                46
#
#            Education    EducationField  EmployeeCount  EmployeeNumber  \
# Attrition
# No                 5  Technical Degree              1             100
# Yes                5  Technical Degree              1              99
#
#            EnvironmentSatisfaction  ... RelationshipSatisfaction  \
# Attrition                           ...
# No                               4  ...                        4
# Yes                              4  ...                        4
#
#            StandardHours  StockOptionLevel  TotalWorkingYears  \
# Attrition
# No                    80                 4                 40
# Yes                   80                 4                 40
#
#           TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# ...

# %%
print((x["Age"]).max)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0     41
# 1     26
# 2     48
# 3     38
# 4     54
#       ..
# 95    54
# 96    39
# 97    51
# 98    38
# 99    23
# Name: Age, Length: 100, dtype: int64>

# %%
g=x.groupby(["Age"])
print(g.get_group(54))
# Out:
#     Age Attrition BusinessTravel  DailyRate       Department  \
# 4    54       Yes     Non-Travel        993         Software
# 46   54        No  Travel_Rarely        431            Sales
# 92   54        No     Non-Travel        647         Hardware
# 95   54        No     Non-Travel       1258  Human Resources
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 4                 22          3          Other              1               5
# 46                 3          2      Marketing              1              47
# 92                22          5        Medical              1              93
# 95                43          4          Other              1              96
#
#     ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 4   ...                         3            80                 2
# 46  ...                         2            80                 1
# 92  ...                         3            80                 2
# ...

# %%
x["Age"].value_counts()
# Out:
# 38    6
# 49    5
# 50    5
# 37    5
# 20    5
# 54    4
# 27    4
# 41    3
# 47    3
# 44    3
# 40    3
# 36    3
# 26    3
# 32    3
# 30    3
# 56    3
# 59    2
# 60    2
# 22    2
# 48    2
# 24    2
# 58    2
# 23    2
# 25    2
# 43    2
# 29    2
# 53    2
# 28    2
# 33    2
# 51    2
# 21    2
# 34    2
# 19    1
# 45    1
# 35    1
# 31    1
# 55    1
# 57    1
# 39    1
# Name: Age, dtype: int64

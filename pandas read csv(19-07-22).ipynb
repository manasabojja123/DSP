# %%
import pandas as pd
a=pd.read_csv("Demo.csv")

# %%
a
# Out:
#     SNO     NAME  MARKS
# 0     1   MANASA    100
# 1     2  LAVANYA     90
# 2     3  SWAROOP     80
# 3     4    RUCHI     50
# 4     5  PRAVEEN    100
# 5     6    RAMYA     90
# 6     7     RAJI     80
# 7     9    SATYA     70
# 8    10   SWARNA     60
# 9    11    VANDU     90
# 10   12   RAVALI     60
# 11   13  SHAREEF     10
# 12   14    TARUN     29
# 13   15     AYUB     37

# %%
import pandas as pd
a=pd.read_csv("work.csv")

# %%
a
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes         Non-Travel        489                Hardware
# 1    26        No         Non-Travel        841                Hardware
# 2    48        No      Travel_Rarely        437         Human Resources
# 3    38       Yes      Travel_Rarely       1403  Research & Development
# 4    54       Yes         Non-Travel        993                Software
# ..  ...       ...                ...        ...                     ...
# 95   54        No         Non-Travel       1258         Human Resources
# 96   39       Yes  Travel_Frequently       1092                 Support
# 97   51        No         Non-Travel        977                Software
# 98   38       Yes  Travel_Frequently        810                Hardware
# 99   23        No         Non-Travel       1222         Human Resources
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
print(a.to_string)
# Out:
# <bound method DataFrame.to_string of     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes         Non-Travel        489                Hardware
# 1    26        No         Non-Travel        841                Hardware
# 2    48        No      Travel_Rarely        437         Human Resources
# 3    38       Yes      Travel_Rarely       1403  Research & Development
# 4    54       Yes         Non-Travel        993                Software
# ..  ...       ...                ...        ...                     ...
# 95   54        No         Non-Travel       1258         Human Resources
# 96   39       Yes  Travel_Frequently       1092                 Support
# 97   51        No         Non-Travel        977                Software
# 98   38       Yes  Travel_Frequently        810                Hardware
# 99   23        No         Non-Travel       1222         Human Resources
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
a.head()
# Out:
#    Age Attrition BusinessTravel  DailyRate              Department  \
# 0   41       Yes     Non-Travel        489                Hardware
# 1   26        No     Non-Travel        841                Hardware
# 2   48        No  Travel_Rarely        437         Human Resources
# 3   38       Yes  Travel_Rarely       1403  Research & Development
# 4   54       Yes     Non-Travel        993                Software
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                 9          1  Technical Degree              1
# 1                39          1           Medical              1
# 2                20          5             Other              1
# 3                38          3   Human Resources              1
# 4                22          3             Other              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0               1  ...                         1            80
# ...

# %%
a.head(50)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes         Non-Travel        489                Hardware
# 1    26        No         Non-Travel        841                Hardware
# 2    48        No      Travel_Rarely        437         Human Resources
# 3    38       Yes      Travel_Rarely       1403  Research & Development
# 4    54       Yes         Non-Travel        993                Software
# 5    27        No  Travel_Frequently        259  Research & Development
# 6    50       Yes  Travel_Frequently        647                Hardware
# 7    58       Yes         Non-Travel        668  Research & Development
# 8    56        No      Travel_Rarely       1031                Software
# 9    28        No  Travel_Frequently       1159         Human Resources
# 10   27        No         Non-Travel        203                Software
# 11   27        No  Travel_Frequently       1304                Hardware
# ...

# %%
a.tail()
# Out:
#     Age Attrition     BusinessTravel  DailyRate       Department  \
# 95   54        No         Non-Travel       1258  Human Resources
# 96   39       Yes  Travel_Frequently       1092          Support
# 97   51        No         Non-Travel        977         Software
# 98   38       Yes  Travel_Frequently        810         Hardware
# 99   23        No         Non-Travel       1222  Human Resources
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# 95                43          4             Other              1
# 96                31          5   Human Resources              1
# 97                14          1  Technical Degree              1
# 98                 4          5   Human Resources              1
# 99                16          4  Technical Degree              1
#
#     EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 95              96  ...                         3            80
# ...

# %%
a.tail(30)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 70   53        No      Travel_Rarely       1068                Hardware
# 71   28       Yes         Non-Travel        511                 Support
# 72   31        No  Travel_Frequently       1469                 Support
# 73   40       Yes  Travel_Frequently       1381                   Sales
# 74   37        No         Non-Travel       1242                Hardware
# 75   19       Yes      Travel_Rarely        383  Research & Development
# 76   36        No  Travel_Frequently        844                   Sales
# 77   45        No  Travel_Frequently       1186         Human Resources
# 78   58        No         Non-Travel       1105                Hardware
# 79   24       Yes  Travel_Frequently        478                   Sales
# 80   47        No      Travel_Rarely       1398                Hardware
# 81   21        No         Non-Travel        268  Research & Development
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       100 non-null    int64
#  1   Attrition                 100 non-null    object
#  2   BusinessTravel            100 non-null    object
#  3   DailyRate                 100 non-null    int64
#  4   Department                100 non-null    object
#  5   DistanceFromHome          100 non-null    int64
#  6   Education                 100 non-null    int64
#  7   EducationField            100 non-null    object
#  8   EmployeeCount             100 non-null    int64
#  9   EmployeeNumber            100 non-null    int64
#  10  EnvironmentSatisfaction   100 non-null    int64
#  11  Gender                    100 non-null    object
#  12  HourlyRate                100 non-null    int64
#  13  JobInvolvement            100 non-null    int64
# ...

# %%
a.loc[55]
# Out:
# Age                                      55
# Attrition                                No
# BusinessTravel                   Non-Travel
# DailyRate                              1467
# Department                          Support
# DistanceFromHome                         34
# Education                                 1
# EducationField              Human Resources
# EmployeeCount                             1
# EmployeeNumber                           56
# EnvironmentSatisfaction                   4
# Gender                                 Male
# HourlyRate                              162
# JobInvolvement                            1
# JobLevel                                  1
# JobRole                           Developer
# JobSatisfaction                           3
# MaritalStatus                       Married
# MonthlyIncome                         32617
# MonthlyRate                           97851
# NumCompaniesWorked                        7
# ...

# %%
a.loc[(a.DailyRate>1400)&(a.Age>40)]
# Out:
#     Age Attrition BusinessTravel  DailyRate              Department  \
# 17   49        No     Non-Travel       1429                Hardware
# 48   57       Yes  Travel_Rarely       1471                 Support
# 55   55        No     Non-Travel       1467                 Support
# 59   56       Yes  Travel_Rarely       1485                 Support
# 61   47       Yes     Non-Travel       1456  Research & Development
# 94   50        No  Travel_Rarely       1434         Human Resources
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# 17                30          5     Life Sciences              1
# 48                10          3         Marketing              1
# 55                34          1   Human Resources              1
# 59                17          5     Life Sciences              1
# 61                28          2  Technical Degree              1
# 94                31          5         Marketing              1
#
# ...

# %%
a["hello"]=["hi"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 a["hello"]=["hi"]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
# ...

# %%
a.iloc[55]

# %%
n=a[(a.DailyRate>1400)&(a.Age>30)]

# %%
n
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 3    38       Yes      Travel_Rarely       1403  Research & Development
# 17   49        No         Non-Travel       1429                Hardware
# 48   57       Yes      Travel_Rarely       1471                 Support
# 55   55        No         Non-Travel       1467                 Support
# 59   56       Yes      Travel_Rarely       1485                 Support
# 61   47       Yes         Non-Travel       1456  Research & Development
# 72   31        No  Travel_Frequently       1469                 Support
# 94   50        No      Travel_Rarely       1434         Human Resources
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# 3                 38          3   Human Resources              1
# 17                30          5     Life Sciences              1
# 48                10          3         Marketing              1
# ...

# %%
n["Age"]
# Out:
# 3     38
# 17    49
# 48    57
# 55    55
# 59    56
# 61    47
# 72    31
# 94    50
# Name: Age, dtype: int64

# %%
a.loc[45,"Age"]
# Out:
# 43

# %%
a.iloc[5:10]
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 5   27        No  Travel_Frequently        259  Research & Development
# 6   50       Yes  Travel_Frequently        647                Hardware
# 7   58       Yes         Non-Travel        668  Research & Development
# 8   56        No      Travel_Rarely       1031                Software
# 9   28        No  Travel_Frequently       1159         Human Resources
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 5                 2          4   Human Resources              1
# 6                42          1     Life Sciences              1
# 7                26          4             Other              1
# 8                23          5           Medical              1
# 9                13          1  Technical Degree              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 5               6  ...                         4            80
# ...

# %%
a.iloc[2,3,4,5,7]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 a.iloc[2,3,4,5,7]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexing.py:1458, in _iLocIndexer._getitem_tuple(self, tup)
#    1456 def _getitem_tuple(self, tup: tuple):
# -> 1458     tup = self._validate_tuple_indexer(tup)
#    1459     with suppress(IndexingError):
#    1460         return self._getitem_lowerdim(tup)
#
# ...

# %%
a.max()
# Out:
# Age                                           60
# Attrition                                    Yes
# BusinessTravel                     Travel_Rarely
# DailyRate                                   1485
# Department                               Support
# DistanceFromHome                              50
# Education                                      5
# EducationField                  Technical Degree
# EmployeeCount                                  1
# EmployeeNumber                               100
# EnvironmentSatisfaction                        4
# Gender                                      Male
# HourlyRate                                   199
# JobInvolvement                                 4
# JobLevel                                       5
# JobRole                     Sales Representative
# JobSatisfaction                                4
# MaritalStatus                             Single
# MonthlyIncome                              50063
# ...

# %%
a.min()
# Out:
# Age                                      19
# Attrition                                No
# BusinessTravel                   Non-Travel
# DailyRate                               112
# Department                         Hardware
# DistanceFromHome                          1
# Education                                 1
# EducationField              Human Resources
# EmployeeCount                             1
# EmployeeNumber                            1
# EnvironmentSatisfaction                   1
# Gender                               Female
# HourlyRate                               32
# JobInvolvement                            1
# JobLevel                                  1
# JobRole                           Developer
# JobSatisfaction                           1
# MaritalStatus                      Divorced
# MonthlyIncome                          2140
# MonthlyRate                           17681
# NumCompaniesWorked                        0
# ...

# %%
import pandas as pd
a=pd.read_csv("work.csv")

# %%
a

# %%
import pandas as pd
print(pd.options.display.max_rows)

# %%
#data cleaning
import pandas as pd
a=pd.read_csv("work.csv")
print(a.to_string)
# Out:
# <bound method DataFrame.to_string of     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes         Non-Travel        489                Hardware
# 1    26        No         Non-Travel        841                Hardware
# 2    48        No      Travel_Rarely        437         Human Resources
# 3    38       Yes      Travel_Rarely       1403  Research & Development
# 4    54       Yes         Non-Travel        993                Software
# ..  ...       ...                ...        ...                     ...
# 95   54        No         Non-Travel       1258         Human Resources
# 96   39       Yes  Travel_Frequently       1092                 Support
# 97   51        No         Non-Travel        977                Software
# 98   38       Yes  Travel_Frequently        810                Hardware
# 99   23        No         Non-Travel       1222         Human Resources
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
import pandas as pd
x=pd.read_csv("work.csv")
x
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes         Non-Travel        489                Hardware
# 1    26        No         Non-Travel        841                Hardware
# 2    48        No      Travel_Rarely        437         Human Resources
# 3    38       Yes      Travel_Rarely       1403  Research & Development
# 4    54       Yes         Non-Travel        993                Software
# ..  ...       ...                ...        ...                     ...
# 95   54        No         Non-Travel       1258         Human Resources
# 96   39       Yes  Travel_Frequently       1092                 Support
# 97   51        No         Non-Travel        977                Software
# 98   38       Yes  Travel_Frequently        810                Hardware
# 99   23        No         Non-Travel       1222         Human Resources
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
x.shape
# Out:
# (100, 35)

# %%
x.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
x.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
x.isna().sum()#check null values
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
x.describe()
# Out:
#               Age    DailyRate  DistanceFromHome   Education  EmployeeCount  \
# count  100.000000   100.000000         100.00000  100.000000          100.0
# mean    38.910000   873.250000          23.54000    3.060000            1.0
# std     11.892698   402.999621          13.99886    1.496258            0.0
# min     19.000000   112.000000           1.00000    1.000000            1.0
# 25%     28.750000   517.750000          12.50000    2.000000            1.0
# 50%     38.000000   891.500000          22.00000    3.000000            1.0
# 75%     49.000000  1226.750000          35.00000    4.000000            1.0
# max     60.000000  1485.000000          50.00000    5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count      100.000000               100.000000  100.000000      100.000000
# mean        50.500000                 2.470000  108.340000        2.390000
# ...
